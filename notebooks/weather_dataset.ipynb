# %%
import zipfile
from pathlib import Path

import numpy as np
import pandas as pd
import xarray as xr
import os

# %%
# Quarter folders
# QUARTERS = ["Q1", "Q2", "Q3", "Q4"]

# Monthly folders
MONTHS = ["JAN", "FEB", "MAR", "APR", "MAY", "JUN", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC"]
# Target coordinate (Azamgarh)
TARGET_LATITUDE = 26.00
TARGET_LONGITUDE = 83.00

# Dataset directory
BASE_DIR = Path('c:\\Users\\Gaurav Sehgal\\OneDrive\\Desktop\\weather_forecasting_system')
DATASET_DIR = BASE_DIR / "data"

# %%
for month in MONTHS:

    zip_path = DATASET_DIR / "archives" / f"azamgarh_weather_{month}_2025.zip"
    extract_path = DATASET_DIR / "raw" / month

    if not zip_path.exists():
        print(f"Archive not found: {zip_path}")
        continue

    extract_path.mkdir(parents=True, exist_ok=True)

    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(extract_path)
        zip_ref.extractall(extract_path)

    print(f"{month} extracted successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       2
#       3     zip_path = DATASET_DIR / "archives" / f"azamgarh_weather_{month}_2025.zip"
#       4     extract_path = DATASET_DIR / "raw" / month
#       5
# ----> 6     with zipfile.ZipFile(zip_path, "r") as zip_ref:
#       7         zip_ref.extractall(extract_path)
#       8
#       9     print(f"{month} extracted successfully.")
#
# File C:\Program Files\Python313\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\Gaurav Sehgal\\OneDrive\\Desktop\\weather_forecasting_system\\data\\archives\\azamgarh_weather_JAN_2025.zip'
